# %% [markdown]
# ## We Rate Dogs-Data Wrangling Project-Act Report

# %% [markdown]
# ### Project Overview

# %% [markdown]
# This project is focused on displaying our data wrangling skills and visualization. The dataset used in the project is is the tweet archive of Twitter known as WeRateDogs. WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog.

# %% [markdown]
# #### Dataset
# These dataset was divided into three
# - The WeRateDogs Enhanced Twitter archive which contains data extracted from weratedogs twitter account, posted between November 15, 2015 and August 1, 2017. This data contains tweet id,dog ratings,dog stage and dog name that were taken from the text of the tweet.
# - The image predictions dataset that was programmatically downloaded,it contains the various image predictions of dog and confidence values
# - The retweet and favorite count dataset that was extracted from twitter API.This contains tweet ids and its favorite and retweet count

# %% [markdown]
# #### Assessing and Cleaning
# For analysis , the above dataset was assessed both visually and programmatically.Several Quality and Tidiness issues were discovered which wouldnt have been great for my analysis,hence these issues werd cleaned as seen in the Wrangle-act notebook.
# After cleaning, the individual dataset were merged into a master document which was used for analysis.

# %% [markdown]
# #### Insights and Visualization
#
# The following questions were generated for the pupose of analysis;
# - Is there any correlation between retweet_count and favorite_count?
# - What is the most commont tweet source?
# - Is there any relationship between tweet source and retweet_count as well as favorite_count?
# - Day of the week with the highest tweet
# - Which dog_stage has the highest retweet and favorites?
# - Top 10 dog breeds based on retweet_count and favorite_count ?

# %% [markdown]
# #### Insight 1- Correlation betweet retweet_count and favorite_count

# %% [markdown]
# The scatter plot below indicated strong positive correlation between retweet_count and favorite_count. Therefore the more the tweets gets retweeted, the tendency for the like to increase is positive.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Insight 2- The most common tweet source

# %% [markdown]
# From the dataset gathered, the tweets sources were originally 4 listed below
# - Twitter for iPhone
# - Twitter Web Client
# - Vine - Make a Scene
# - TweetDeck
#
# After cleaning, Vine- Make a scene was eliminated. The below represents a smaller sample of the overall dataset.
# As shown in the visualization below, the most common tweet source is 'Twitter for iPhone'.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Insight 3- Tweet source relationship with retweet count and favorite count

# %% [markdown]
# From the visualization below, The most common tweet source has the highest average retweet and favorite count.This could also be as a result of other factors.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Insight 4- Day of the week with the highest tweet.

# %% [markdown]
# From the visualization below, **Monday** has the highest number of tweets, followed by friday and thursday. With this i can say i look forward to seeing new dog tweets on mondays.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Insight 5-Dog stage with highest retweet and favorite count

# %% [markdown]
# The various unique dog stages present in the dataset includes doggo,puppo,floof,pupper,doggo-puppo,doggor-pupper. From the visualization below, **Doggo-Puppo** has the highest average retweets and favorite count.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Insight 6-Top 10 dog breeds based on retweet_count and favorite_count

# %% [markdown]
# The barchart below shows the top 10 dog breed ranked by retweet count and favorite count. The top dog breed is **Golden_retriever** having the highest retweet and likes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Limitations
# - The dataset contains lots of missing information hence affecting the adequacy of insights derived.
# - Inability to extract information for 29 tweet ids using the twitter Api

# %% [markdown]
# ### Conclusion
# From executing this project, i understood perfectly the importance of data wrangling, There is indeed lots of data out in the world but most of this data requires wrangling so as to provide accurate and reliable insights.
# Through this project,i learnt new pandas functions and its applicability.In general,it was FUN.
